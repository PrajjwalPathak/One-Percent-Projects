# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_INTERN_GOOGLE.csv")
a
# Out:
#     INTERN  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
# 0        7         6          4        4      0         2       2         2
# 1        9       120          2        0      0         3       2         1
# 2       10         0          0        0      0         0       0         0
# 3       15         0         48      294      0        10      76        26
# 4       18       840        186        0      0         0       0         0
# 5       22       558          4      210      0       122     236       138
# 6       47         0          0      312      0         2      34         0
# 7       52         0          0        0      0         0       0         0
# 8       53         8         20        0      0         0       0         0
# 9       55       112          0        0      0        22     168         0
# 10      57         0          0        0      0         0      26         0
# ...

# %%
a.shape
# Out:
# (46, 12)

# %%
plt.plot(a['INTERN'])
plt.plot(a['FACEBOOK'])

# %%
fig, axs = plt.subplots(4, 3)
axs[0, 0].plot(a['INTERN'])

axs[0, 1].plot(a['FACEBOOK'])
axs[0, 2].plot(a['INSTAGRAM'])
axs[1, 0].plot(a['TWITTER'])
axs[1, 1].plot(a['QUORA'])
axs[1, 2].plot(a['LINKEDIN'])
axs[2, 0].plot(a['REDDIT'])
axs[2, 1].plot(a['SNAPCHAT'])
axs[2, 2].plot(a['YOUTUBE'])
axs[3, 0].plot(a['TIKTOK'])
axs[3, 1].plot(a['EMAIL'])
axs[3, 2].plot(a['OTHER'])
