# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('CONSOLE_DIGITAL_MARKETING_PLATFORM_APP_GOOGLE.csv')
data
# Out:
#                     APP  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  \
# 0            C Compiler       497        137      139     79        65
# 1            C Tutorial       496        153      127     86        36
# 2           C# Compiler       226         95      846     10        73
# 3           C# Tutorial       349         86      200     11        55
# 4          C++ Compiler       248        129      338     23        68
# 5          C++ Tutorial       429        131      469     63        49
# 6           Calculator+       615         63      122     46        25
# 7             Calendar+       521        149      158     16        29
# 8             Compiler+       502        125      181     78        26
# 9          CSS Tutorial       189        141       99     16        23
# 10        Dart Compiler        35         45      314      1        17
# 11        Dart Tutorial        60         23       39      7        18
# ...

# %% [markdown]
# ## The Bar Graph below shows the total view count for all the apps and tutorials on all the platforms
# - If the total view count for any platform is less, then the all the apps and tutorials should be promoted on that platform.

# %%
x = []
y = []
for slug in data:
    x.append(slug)
x = x[1:]
for slug in x:
    y.append(int(sum(data[slug])))
plt.figure(figsize=(20,10))
plt.title('Bar Graph showing total view count for all the apps and tutorials on all the platforms', fontsize=20)
plt.xlabel('Platforms', fontsize=15)
plt.ylabel('View Count', fontsize=15)
plt.bar(x, y, color='g')
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# - According to the graph above, INSTAGRAM, LINKEDIN, REDDIT, SNAPCHAT, YOUTUBE, TIKTOK, EMAIL and OTHER are the platforms that have very low total view count. All the apps and tutorials must be promoted on these platforms.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## The Plot Graphs below show the view count of each app or each tutorial by the period of time forindividual platforms
# - If the view count of an app or a tutorial has a low total view count, then it needs to be promoted on that particular platform.

# %%
y = data['APP']
promotions = []
plt.figure(figsize=(20, 125))
for i in range(1,12):
    promotion = []
    plt.subplot(12, 1, i)
    plt.barh(y, data[x[i-1]])
    counter = 0
    for count in data[x[i-1]]:
        if count <= 10:
            promotion.append(y[counter])
        counter = counter + 1
    promotions.append(promotion)
    plt.title(x[i-1], fontsize=15)
    plt.xlabel("View Count", fontsize=15)
    plt.ylabel("Platforms", fontsize=15)

# %% [markdown]
# ### Conclusions - These are the apps and tutorials that must be updated

# %%
for i in range(1,12):
    print(x[i-1] + ' - ', end ="")
    for j in promotions[i-1]:
        print(j + ', ', end =" ")  
    print('\n')
# Out:
# FACEBOOK - Dictionary,
#
# INSTAGRAM - Dictionary,
#
# TWITTER - Kotlin Tutorial,  Dictionary,
#
# QUORA - C# Compiler,  Dart Compiler,  Dart Tutorial,  Kotlin Compiler,  Kotlin Tutorial,  PHP Compiler,  Ruby Tutorial,  Tasks+,  Time+,
#
# LINKEDIN - Kotlin Compiler,  Kotlin Tutorial,  Ruby Tutorial,  Dictionary,
#
# REDDIT - Message+,  Dictionary,
#
# SNAPCHAT - C# Tutorial,  CSS Tutorial,  Dart Tutorial,  HTML Tutorial,  Kotlin Tutorial,  PHP Compiler,  Ruby Compiler,  Ruby Tutorial,  Swift Compiler,  Swift Tutorial,  Tasks+,  Travel Diaries,  XML Tutorial,  Message+,  Dictionary,
#
# YOUTUBE - Calculator+,  Dart Compiler,  Dart Tutorial,  Go Compiler,  Go Tutorial,  Kotlin Compiler,  Kotlin Tutorial,  Motivation+,  PHP Compiler,  PHP Tutorial,  Ruby Compiler,  Ruby Tutorial,  Success Stories,  Swift Compiler,  Swift Tutorial,  Tasks+,  Travel Diaries,  Dictionary,
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ---
