# %%
import pandas as pd
import numpy
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# ### Understanding the dataset

# %%
a=pd.read_csv("csvDumps/CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_APPLE.csv")
a["INDEX"] = [i for i  in range(0,320)]
a.to_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_APPLE.csv", index=False)
a
# Out:
#            DATE  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  \
# 0    28-05-2021         0          0        0      0         0       0
# 1    29-05-2021         0          0        0      0         0       0
# 2    30-05-2021         0          0        0      0         0       0
# 3    31-05-2021         0          0        0      0         0       0
# 4    01-06-2021         0          0        0      0         0       0
# ..          ...       ...        ...      ...    ...       ...     ...
# 315  27-01-2022         0          0        0      0         0       6
# 316  28-01-2022         0          0        0      0         0       6
# 317  29-01-2022         0          0        0      0         0       5
# 318  31-01-2022         0          0        0      0         0       2
# 319  16-01-2022         0          0        0      2         0       0
#
#      SNAPCHAT  YOUTUBE  TIKTOK  EMAIL  OTHER  INDEX
# 0           0        0       0      0      0      0
# ...

# %%
label=["FACEBOOK","INSTAGRAM","TWITTER","QUORA","LINKEDIN","REDDIT","SNAPCHAT","YOUTUBE","TIKTOK","EMAIL","OTHER"]

# %%
a.shape
# Out:
# (320, 13)

# %%
total_views=[int(sum(a['FACEBOOK'])),int(sum(a['INSTAGRAM'])),int(sum(a['TWITTER'])),int(sum(a['QUORA'])),int(sum(a['LINKEDIN'])),int(sum(a['REDDIT'])),int(sum(a['SNAPCHAT'])),int(sum(a['YOUTUBE'])),int(sum(a['TIKTOK'])),int(sum(a['EMAIL'])),int(sum(a['OTHER']))]
total_views
# Out:
# [1176, 297, 823, 998, 257, 255, 31, 257, 0, 62, 266]

# %% [markdown]
# ### Plotting every view of each platform against date
#
# This section plots every view of each app on a single graph.
#
# As we understand from the graph, the engagement of the apps is very less. We have 320 days available in the datasets. For each data, only the ending few days have some views.
#
# Out of them, Facebook, Instagram, Twitter, Quora, Linkedin have better views in the last few days. Whereas, the rest have very less views, especially emails and tiktok.
#
# Observe the graphs for better understanding

# %%
plt.figure(figsize=(20,10))
plt.plot(a["INDEX"],a["FACEBOOK"],"-.")
plt.plot(a["INDEX"],a["INSTAGRAM"],":")
plt.plot(a["INDEX"],a["TWITTER"],"--")
plt.plot(a["INDEX"],a["QUORA"])
plt.plot(a["INDEX"],a["LINKEDIN"])
plt.plot(a["INDEX"],a["REDDIT"])
plt.plot(a["INDEX"],a["SNAPCHAT"],":")
plt.plot(a["INDEX"],a["YOUTUBE"],"--")
plt.plot(a["INDEX"],a["TIKTOK"])
plt.plot(a["INDEX"],a["EMAIL"])
plt.plot(a["INDEX"],a["OTHER"])
plt.legend(label)
plt.show()

# %% [markdown]
# ### Zooming the graph towards the end of the date timeline for better understanding

# %%
plt.figure(figsize=(20,10))
plt.plot(a["INDEX"],a["FACEBOOK"],"-.")
plt.plot(a["INDEX"],a["INSTAGRAM"],":")
plt.plot(a["INDEX"],a["TWITTER"],"--")
plt.plot(a["INDEX"],a["QUORA"])
plt.plot(a["INDEX"],a["LINKEDIN"])
plt.plot(a["INDEX"],a["REDDIT"])
plt.plot(a["INDEX"],a["SNAPCHAT"],":")
plt.plot(a["INDEX"],a["YOUTUBE"],"--")
plt.plot(a["INDEX"],a["TIKTOK"])
plt.plot(a["INDEX"],a["EMAIL"])
plt.plot(a["INDEX"],a["OTHER"])
plt.axis([245, 0, 0, 0])
plt.legend(label)
ax=plt.gca()
ax.set_xlim([230,325])
ax.set_ylim([0,100])
plt.show()

# %% [markdown]
# ### Plotting of sum of views for each platform for an overall analysis

# %%
plt.pie(total_views,labels=label,autopct='%.0f%%')
plt.title("PIECHART DEPICTING THE SUM OF ALL VISITS IN EACH PLATFORM")
plt.show()

# %%
label_short=["FB","IG","TW","QRA","LN","RDT","SNP","UT","TT","EM","O"]
sns.barplot(x=label_short, y=total_views)
plt.title("BARPLOT DEPICTING THE SUM OF ALL VIEWS FOR EACH PLATFORM")
plt.show()

# %% [markdown]
# ### Individual Analysis of each platform
#
# This section plots the views of each app on different graphs for better comparison.
#
# As we understand from these plots, the views of every app, is not at all constant with 0 views for the major 1st part of the graph. We are comparing the results on the basis of the views obtained in the last few days.
#
# Facebook, Instagram, Linkedin, Quora and Twitter have better views comparatively.
# The rest have lesser views.

# %%
fig, ax = plt.subplots(4, 3)
#sns.scatterplot(y=a['INTERN'],x=a['INDEX'] ,ax=ax[0,0]).set_title("INTERN")
sns.scatterplot(y=a['FACEBOOK'],x=a['INDEX'], ax=ax[0,1]).set_title("FACEBOOK")
sns.scatterplot(y=a['INSTAGRAM'],x=a['INDEX'] ,ax=ax[0,2]).set_title("INSTAGRAM")
sns.scatterplot(y=a['TWITTER'],x=a['INDEX'] ,ax=ax[1,0]).set_title("TWITTER")
sns.scatterplot(y=a['QUORA'],x=a['INDEX'] ,ax=ax[1,1]).set_title("QUORA")
sns.scatterplot(y=a['LINKEDIN'],x=a['INDEX'] ,ax=ax[1,2]).set_title("LINKEDIN")
sns.scatterplot(y=a['REDDIT'],x=a['INDEX'] ,ax=ax[2,0]).set_title("REDDIT")
sns.scatterplot(y=a['SNAPCHAT'],x=a['INDEX'] ,ax=ax[2,1]).set_title("SNAPCHAT")
sns.scatterplot(y=a['YOUTUBE'],x=a['INDEX'] ,ax=ax[2,2]).set_title("YOUTUBE")
sns.scatterplot(y=a['TIKTOK'],x=a['INDEX'] ,ax=ax[3,0]).set_title("TIKTOK")
sns.scatterplot(y=a['EMAIL'],x=a['INDEX'] ,ax=ax[3,1]).set_title("EMAIL")
sns.scatterplot(y=a['OTHER'],x=a['INDEX'] ,ax=ax[0,0]).set_title("OTHER")
# Out:
# Text(0.5, 1.0, 'OTHER')

# %% [markdown]
# ### Costructive analysis of well-viewed apps
#
# The apps here are : Facebook, Instagram, Linkedin, Quora and Twitter.
#
# As we observe from the graph, all the apps have thicker views at the end of the date timeline.

# %%
#facebook, instagram, twitter, quora and linkedin



fig, ax = plt.subplots(5, 2)

sns.distplot(a['FACEBOOK'], ax=ax[0,0]).set_title("FACEBOOK")
sns.scatterplot(y=a['FACEBOOK'],x=a['INDEX'], ax=ax[0,1]).set_title("FACEBOOK")
sns.distplot(a['INSTAGRAM'],ax=ax[1,0]).set_title("INSTAGRAM")
sns.scatterplot(y=a['INSTAGRAM'],x=a['INDEX'] ,ax=ax[1,1]).set_title("INSTAGRAM")
sns.distplot(a['LINKEDIN'],ax=ax[2,0]).set_title("LINKEDIN")
sns.scatterplot(y=a['LINKEDIN'],x=a['INDEX'] ,ax=ax[2,1]).set_title("LINKEDIN")
sns.distplot(a['TWITTER'],ax=ax[3,0]).set_title("TWITTER")
sns.scatterplot(y=a['TWITTER'],x=a['INDEX'] ,ax=ax[3,1]).set_title("TWITTER")
sns.distplot(a['QUORA'],ax=ax[4,0]).set_title("QUORA")
sns.scatterplot(y=a['QUORA'],x=a['INDEX'] ,ax=ax[4,1]).set_title("QUORA")
# Out:
# Text(0.5, 1.0, 'QUORA')

# %%
plt.plot(a['FACEBOOK'])
plt.plot(a['INSTAGRAM'])
plt.plot(a['LINKEDIN'],"-.")
plt.plot(a['TWITTER'],":")
plt.plot(a['QUORA'],":")
plt.legend(["FACEBOOK","INSTAGRAM","LINKEDIN","TWITTER","QUORA"],loc="upper left")

# %%
plt.plot(a['FACEBOOK'])
plt.plot(a['INSTAGRAM'])
plt.plot(a['LINKEDIN'],"-.")
plt.plot(a['TWITTER'],":")
plt.plot(a['QUORA'],":")
plt.legend(["FACEBOOK","INSTAGRAM","LINKEDIN","TWITTER","QUORA"],loc="upper left")
ax=plt.gca()
ax.set_xlim([230,325])
ax.set_ylim([0,100])
# Out:
# (0.0, 100.0)

# %% [markdown]
# ### Constructive analysis of less-viewed apps
#
# As the name suggests, this section depicts the lesser viewed apps.
#
# Out of these, Youtube, Reddit and Other consists of comparatively slightly more views than the rest.
#
# Snapchat, Email and Tiktoks have very scanty plots that clearly helps us understand the views.

# %%
fig, ax = plt.subplots(2, 3)
sns.scatterplot(y=a['REDDIT'],x=a['INDEX'] ,ax=ax[0,0]).set_title("REDDIT")
sns.scatterplot(y=a['SNAPCHAT'],x=a['INDEX'] ,ax=ax[0,1]).set_title("SNAPCHAT")
sns.scatterplot(y=a['YOUTUBE'],x=a['INDEX'] ,ax=ax[0,2]).set_title("YOUTUBE")
sns.scatterplot(y=a['TIKTOK'],x=a['INDEX'] ,ax=ax[1,0]).set_title("TIKTOK")
sns.scatterplot(y=a['EMAIL'],x=a['INDEX'] ,ax=ax[1,1]).set_title("EMAIL")
sns.scatterplot(y=a['OTHER'],x=a['INDEX'] ,ax=ax[1,2]).set_title("OTHER")
# Out:
# Text(0.5, 1.0, 'OTHER')

# %%
plt.plot(a['SNAPCHAT'])
plt.plot(a['REDDIT'],"-.")
plt.plot(a['YOUTUBE'])
plt.plot(a['TIKTOK'],":")
plt.plot(a['OTHER'])
plt.legend(["TWITTER","QUORA","YOUTUBE","TIKTOK","EMAIL","OTHER"],loc="upper right")

# %%
plt.plot(a['SNAPCHAT'])
plt.plot(a['REDDIT'],"-.")
plt.plot(a['YOUTUBE'])
plt.plot(a['TIKTOK'],":")
plt.plot(a['OTHER'])
plt.legend(["TWITTER","QUORA","YOUTUBE","TIKTOK","EMAIL","OTHER"],loc="upper right")
ax=plt.gca()
ax.set_xlim([230,325])
ax.set_ylim([0,100])
# Out:
# (0.0, 100.0)
