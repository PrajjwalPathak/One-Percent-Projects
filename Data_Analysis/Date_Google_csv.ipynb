# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")

# %% [markdown]
# ### Understanding the dataset

# %%
a=pd.read_csv("csvDumps/CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv")
a["INDEX"] = [i for i  in range(0,320)]
a.to_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv", index=False)
a
# Out:
#            DATE  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  \
# 0    28-05-2021         2          0        0      0         3      35
# 1    29-05-2021       116          1        0      0         0      18
# 2    30-05-2021        10          6        0      0         5      31
# 3    31-05-2021        39          0        1      0         1      70
# 4    01-06-2021        77         17        0      0         5      18
# ..          ...       ...        ...      ...    ...       ...     ...
# 315  27-01-2022         0          0        0      0         0       0
# 316  28-01-2022         0          0        0      0         0       0
# 317  29-01-2022         0          0        0      0         0       0
# 318  31-01-2022         0          0        0      0         0       0
# 319  16-01-2022         0          0        0      0         0       0
#
#      SNAPCHAT  YOUTUBE  TIKTOK  EMAIL  OTHER  INDEX
# 0           4        0       0      0      9      0
# ...

# %%
label=["FACEBOOK","INSTAGRAM","TWITTER","QUORA","LINKEDIN","REDDIT","SNAPCHAT","YOUTUBE","TIKTOK","EMAIL","OTHER"]

# %%
a.shape
# Out:
# (320, 13)

# %%
total_views=[int(sum(a['FACEBOOK'])),int(sum(a['INSTAGRAM'])),int(sum(a['TWITTER'])),int(sum(a['QUORA'])),int(sum(a['LINKEDIN'])),int(sum(a['REDDIT'])),int(sum(a['SNAPCHAT'])),int(sum(a['YOUTUBE'])),int(sum(a['TIKTOK'])),int(sum(a['EMAIL'])),int(sum(a['OTHER']))]
total_views
# Out:
# [10177, 3592, 7136, 1343, 1289, 7338, 845, 737, 0, 177, 1976]

# %% [markdown]
# ### Plotting every view of each platform against date
#
# This section plots every view of each platform against the respective date.
#
# As we understand, while Facebook, Instagram, Snapchat, LinkedIn and Reddit are well-used platform, the rest lack the required public engagement.
#
# The well-viewed platforms are identified from the graphs, where in all 320 days, the view is high. Similarly, the less viewed platforms have 320 rows with nearly 0 to less number of views, or even a high view on only 2-3 days max.

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(y=a['FACEBOOK'],x=a['INDEX'])
sns.scatterplot(y=a['INSTAGRAM'],x=a['INDEX'])
sns.scatterplot(y=a['TWITTER'],x=a['INDEX'])
sns.scatterplot(y=a['QUORA'],x=a['INDEX'])
sns.scatterplot(y=a['LINKEDIN'],x=a['INDEX'])
sns.scatterplot(y=a['REDDIT'],x=a['INDEX'])
sns.scatterplot(y=a['SNAPCHAT'],x=a['INDEX'])
sns.scatterplot(y=a['YOUTUBE'],x=a['INDEX'])
sns.scatterplot(y=a['TIKTOK'],x=a['INDEX'])
sns.scatterplot(y=a['EMAIL'],x=a['INDEX'])
sns.scatterplot(y=a['OTHER'],x=a['INDEX'])
plt.legend(label)
plt.figure(figsize=(20,20))

# %% [markdown]
# ### Plotting of sum of views for each platform for an overall analysis

# %%
plt.pie(total_views,labels=label,autopct='%.0f%%')
plt.title("PIECHART DEPICTING THE SUM OF ALL VISITS IN EACH PLATFORM")
plt.show()

# %%
label_short=["FB","IG","TW","QRA","LN","RDT","SNP","UT","TT","EM","O"]
sns.barplot(x=label_short, y=total_views)
plt.title("BARPLOT DEPICTING THE SUM OF ALL VIEWS FOR EACH PLATFORM")
plt.show()

# %% [markdown]
# ### Individual Analysis of each platform
#
# As mentioned, from the graph it is clear that the well-viewed apps include - Facebook, Instagram, Linkedin, reddit, snapchat, and likewise the rest fall under the less-viewed apps. For example, "Email" and "Tiktok" have almost 0 to no views at all in all the 320 days.
#
# Youtube and Quora have high views at the end of the graph. This means that only on certain end days, it has been used well. We want apps to be used daily. Hence a little focus is needed here as well.

# %%
fig, axs = plt.subplots(4, 3)
axs[0, 1].plot(a['FACEBOOK'])
axs[0, 1].set_title("FACEBOOK")
axs[0, 2].plot(a['INSTAGRAM'])
axs[0, 2].set_title("INSTAGRAM")
axs[1, 0].plot(a['TWITTER'])
axs[1, 0].set_title("TWITTER")
axs[1, 1].plot(a['QUORA'])
axs[1, 1].set_title("QUORA")
axs[1, 2].plot(a['LINKEDIN'])
axs[1, 2].set_title("LINKEDIN")
axs[2, 0].plot(a['REDDIT'])
axs[2, 0].set_title("REDDIT")
axs[2, 1].plot(a['SNAPCHAT'])
axs[2, 1].set_title("SNAPCHAT")
axs[2, 2].plot(a['YOUTUBE'])
axs[2, 2].set_title("YOUTUBE")
axs[3, 0].plot(a['TIKTOK'])
axs[3, 0].set_title("TIKTOK")
axs[3, 1].plot(a['EMAIL'])
axs[3, 1].set_title("EMAIL")
axs[0, 0].plot(a['OTHER'])
axs[0, 0].set_title("OTHERS")
plt.show()

# %% [markdown]
# ### Costructive analysis of well-viewed apps
#
# The apps here are : Facebook, Instagram, Linkedin, Reddit and Snapchat
#
# As we observe from the graph, Facebook and Snapchat are very well-viewed by users on a daily basis
#
# Instagram has lesser views than normal, hence more attention is needed.
#
# LinkedIn and Reddit do have good views but lesser than Facebook and snapchat.

# %%
fig, ax = plt.subplots(5, 2)

sns.distplot(a['FACEBOOK'], ax=ax[0,0]).set_title("FACEBOOK")
sns.scatterplot(y=a['FACEBOOK'],x=a['INDEX'], ax=ax[0,1]).set_title("FACEBOOK")
sns.distplot(a['INSTAGRAM'],ax=ax[1,0]).set_title("INSTAGRAM")
sns.scatterplot(y=a['INSTAGRAM'],x=a['INDEX'] ,ax=ax[1,1]).set_title("INSTAGRAM")
sns.distplot(a['LINKEDIN'],ax=ax[2,0]).set_title("LINKEDIN")
sns.scatterplot(y=a['LINKEDIN'],x=a['INDEX'] ,ax=ax[2,1]).set_title("LINKEDIN")
sns.distplot(a['REDDIT'],ax=ax[3,0]).set_title("REDDIT")
sns.scatterplot(y=a['REDDIT'],x=a['INDEX'] ,ax=ax[3,1]).set_title("REDDIT")
sns.distplot(a['SNAPCHAT'],ax=ax[4,0]).set_title("SNAPCHAT")
sns.scatterplot(y=a['SNAPCHAT'],x=a['INDEX'] ,ax=ax[4,1]).set_title("SNAPCHAT")
# Out:
# Text(0.5, 1.0, 'SNAPCHAT')

# %% [markdown]
# ### Constructive analysis of less-viewed apps
#
# Twitter has the most views among this lot, although less yet better than the others.
#
# Youtube and Quora have 0 views since most of the days, but 3-4 days at the end, we see a striking increase, which again diminishes.
#
# Tiktok has 0 views all through out, along with Email that has very scanty views all throughout.

# %%
fig, ax = plt.subplots(2, 3)
sns.scatterplot(y=a['TWITTER'],x=a['INDEX'] ,ax=ax[0,0]).set_title("TWITTER")
sns.scatterplot(y=a['QUORA'],x=a['INDEX'] ,ax=ax[0,1]).set_title("QUORA")
sns.scatterplot(y=a['YOUTUBE'],x=a['INDEX'] ,ax=ax[0,2]).set_title("YOUTUBE")
sns.scatterplot(y=a['TIKTOK'],x=a['INDEX'] ,ax=ax[1,0]).set_title("TIKTOK")
sns.scatterplot(y=a['EMAIL'],x=a['INDEX'] ,ax=ax[1,1]).set_title("EMAIL")
sns.scatterplot(y=a['OTHER'],x=a['INDEX'] ,ax=ax[1,2]).set_title("OTHER")
# Out:
# Text(0.5, 1.0, 'OTHER')

# %% [markdown]
# ### Model For Prediction

# %%
b=pd.read_csv("csvDumps\CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv",index_col='DATE',parse_dates=True)
b
# Out:
#             FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
# DATE
# 2021-05-28         2          0        0      0         3      35         4
# 2021-05-29       116          1        0      0         0      18         2
# 2021-05-30        10          6        0      0         5      31         5
# 2021-05-31        39          0        1      0         1      70         2
# 2021-01-06        77         17        0      0         5      18         0
# ...              ...        ...      ...    ...       ...     ...       ...
# 2022-01-27         0          0        0      0         0       0         0
# 2022-01-28         0          0        0      0         0       0         0
# 2022-01-29         0          0        0      0         0       0         0
# 2022-01-31         0          0        0      0         0       0         0
# 2022-01-16         0          0        0      0         0       0         0
#
#             YOUTUBE  TIKTOK  EMAIL  OTHER
# DATE
# ...

# %%
len(b)
# Out:
# 320

# %%
train = b.iloc[:280,0:1]
test = b.iloc[280:,0:1]

# %%
train
# Out:
#             FACEBOOK
# DATE
# 2021-05-28         2
# 2021-05-29       116
# 2021-05-30        10
# 2021-05-31        39
# 2021-01-06        77
# ...              ...
# 2021-12-12        50
# 2021-12-13        56
# 2021-12-14        59
# 2021-12-15        25
# 2021-12-16       107
#
# [280 rows x 1 columns]

# %%
b.dtypes
# Out:
# FACEBOOK     int64
# INSTAGRAM    int64
# TWITTER      int64
# QUORA        int64
# LINKEDIN     int64
# REDDIT       int64
# SNAPCHAT     int64
# YOUTUBE      int64
# TIKTOK       int64
# EMAIL        int64
# OTHER        int64
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
b.head(),b.tail()
# Out:
# (            FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
#  DATE
#  2021-05-28         2          0        0      0         3      35         4
#  2021-05-29       116          1        0      0         0      18         2
#  2021-05-30        10          6        0      0         5      31         5
#  2021-05-31        39          0        1      0         1      70         2
#  2021-01-06        77         17        0      0         5      18         0
#
#              YOUTUBE  TIKTOK  EMAIL  OTHER
#  DATE
#  2021-05-28        0       0      0      9
#  2021-05-29        0       0      0      0
#  2021-05-30        0       0      0      1
#  2021-05-31        0       0      0      0
#  2021-01-06        0       0      0      2  ,
#              FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
#  DATE
#  2022-01-27         0          0        0      0         0       0         0
# ...

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.00687285],
#        [0.39862543],
#        [0.03436426],
#        [0.13402062],
#        [0.26460481],
#        [0.17869416],
#        [0.18213058],
#        [0.05841924],
#        [0.08591065],
#        [0.48109966]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
n_input = 30
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation, Dropout

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(n_input, n_features)))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_11 (LSTM)              (None, 30, 50)            10400
#
#  dropout_11 (Dropout)        (None, 30, 50)            0
#
#  lstm_12 (LSTM)              (None, 30, 50)            20200
#
#  dropout_12 (Dropout)        (None, 30, 50)            0
#
#  lstm_13 (LSTM)              (None, 30, 50)            20200
#
#  dropout_13 (Dropout)        (None, 30, 50)            0
#
#  lstm_14 (LSTM)              (None, 50)                20200
#
#  dropout_14 (Dropout)        (None, 50)                0
#
#  dense_3 (Dense)             (None, 1)                 51
#
# ...
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 36s 83ms/step - loss: 0.0236
# Epoch 2/100
# 250/250 [==============================] - 21s 85ms/step - loss: 0.0224
# Epoch 3/100
# 250/250 [==============================] - 21s 83ms/step - loss: 0.0221
# Epoch 4/100
# 250/250 [==============================] - 21s 83ms/step - loss: 0.0223
# Epoch 5/100
# 250/250 [==============================] - 21s 84ms/step - loss: 0.0208
# Epoch 6/100
# 250/250 [==============================] - 21s 84ms/step - loss: 0.0208
# Epoch 7/100
# 250/250 [==============================] - 21s 83ms/step - loss: 0.0214
# Epoch 8/100
# 250/250 [==============================] - 21s 84ms/step - loss: 0.0196
# Epoch 9/100
# 250/250 [==============================] - 21s 83ms/step - loss: 0.0197
# Epoch 10/100
# 250/250 [==============================] - 21s 84ms/step - loss: 0.0197
# Epoch 11/100
# 250/250 [==============================] - 21s 84ms/step - loss: 0.0195
# Epoch 12/100
# ...

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.21285167], dtype=float32),
#  array([0.2191616], dtype=float32),
#  array([0.25143322], dtype=float32),
#  array([0.30829528], dtype=float32),
#  array([0.26963243], dtype=float32),
#  array([0.25572714], dtype=float32),
#  array([0.2762033], dtype=float32),
#  array([0.34007165], dtype=float32),
#  array([0.28662324], dtype=float32),
#  array([0.25298464], dtype=float32),
#  array([0.27261177], dtype=float32),
#  array([0.3509231], dtype=float32),
#  array([0.27108157], dtype=float32),
#  array([0.24935737], dtype=float32),
#  array([0.27439135], dtype=float32),
#  array([0.3484917], dtype=float32),
#  array([0.2622447], dtype=float32),
#  array([0.24473774], dtype=float32),
#  array([0.27653047], dtype=float32),
#  array([0.3602694], dtype=float32),
#  array([0.25480038], dtype=float32),
#  array([0.2501766], dtype=float32),
#  array([0.3449808], dtype=float32),
#  array([0.30244887], dtype=float32),
#  array([0.24663132], dtype=float32),
# ...

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['Predictions'] = true_predictions

# %%
test
# Out:
#             FACEBOOK  Predictions
# DATE
# 2021-12-17        34    61.939837
# 2021-12-18        33    63.776026
# 2021-12-19        44    73.167068
# 2021-12-20        48    89.713926
# 2021-12-21        92    78.463037
# 2021-12-22        48    74.416598
# 2021-12-23        54    80.375162
# 2021-12-24        44    98.960850
# 2021-12-25        40    83.407363
# 2021-12-26         0    73.618531
# 2021-12-27         2    79.330024
# 2021-12-28         2   102.118620
# 2021-12-29         0    78.884736
# 2021-12-30         0    72.562995
# 2021-12-31         0    79.847884
# 2022-01-01         0   101.411084
# 2022-02-01         0    76.313208
# 2022-03-01        29    71.218684
# 2022-04-01         0    80.470368
# 2022-05-01         0   104.838395
# 2022-06-01         0    74.146910
# 2022-07-01         0    72.801393
# 2022-08-01         4   100.389415
# 2022-09-01         0    88.012621
# 2022-10-01         0    71.769715
# 2022-11-01         7    82.886346
# ...

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(test_predictions,true_predictions))
# Out:
# 80.3309758529067

# %%
train = b.iloc[:280,1:2]
test = b.iloc[280:,1:2]

# %%
test
# Out:
#             INSTAGRAM
# DATE
# 2021-12-17         31
# 2021-12-18         44
# 2021-12-19         38
# 2021-12-20         38
# 2021-12-21         32
# 2021-12-22         42
# 2021-12-23         46
# 2021-12-24         44
# 2021-12-25         57
# 2021-12-26          6
# 2021-12-27          1
# 2021-12-28          0
# 2021-12-29          2
# 2021-12-30          4
# 2021-12-31          1
# 2022-01-01          0
# 2022-02-01          0
# 2022-03-01          4
# 2022-04-01          2
# 2022-05-01          1
# 2022-06-01          0
# 2022-07-01          0
# 2022-08-01          7
# 2022-09-01          1
# 2022-10-01          1
# 2022-11-01          0
# 2022-12-01          0
# 2022-01-13          0
# 2022-01-14          5
# 2022-01-15          2
# 2022-01-19          0
# 2022-01-21          0
# 2022-01-22          0
# 2022-01-24          0
# 2022-01-25          0
# 2022-01-27          0
# 2022-01-28          0
# 2022-01-29          0
# 2022-01-31          0
# 2022-01-16          0

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
n_input = 30
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(n_input, n_features)))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 50)            10400
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_1 (LSTM)               (None, 30, 50)            20200
#
#  dropout_1 (Dropout)         (None, 30, 50)            0
#
#  lstm_2 (LSTM)               (None, 30, 50)            20200
#
#  dropout_2 (Dropout)         (None, 30, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 18s 46ms/step - loss: 0.0300
# Epoch 2/100
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0262
# Epoch 3/100
# 250/250 [==============================] - 13s 51ms/step - loss: 0.0246
# Epoch 4/100
# 250/250 [==============================] - 10s 41ms/step - loss: 0.0224
# Epoch 5/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0223
# Epoch 6/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0208
# Epoch 7/100
# 250/250 [==============================] - 14s 57ms/step - loss: 0.0194
# Epoch 8/100
# 250/250 [==============================] - 14s 55ms/step - loss: 0.0186
# Epoch 9/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0176
# Epoch 10/100
# 250/250 [==============================] - 9s 34ms/step - loss: 0.0191
# Epoch 11/100
# 250/250 [==============================] - 9s 36ms/step - loss: 0.0155
# Epoch 12/100
# ...

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['Predictions'] = true_predictions

test
# Out:
#             INSTAGRAM  Predictions
# DATE
# 2021-12-17         31    11.083940
# 2021-12-18         44     5.375520
# 2021-12-19         38     0.819816
# 2021-12-20         38    -0.568912
# 2021-12-21         32     1.787910
# 2021-12-22         42     6.253679
# 2021-12-23         46     9.897394
# 2021-12-24         44    10.586416
# 2021-12-25         57     9.036003
# 2021-12-26          6     7.410990
# 2021-12-27          1     6.613661
# 2021-12-28          0     5.680701
# 2021-12-29          2     4.142669
# 2021-12-30          4     2.637453
# 2021-12-31          1     1.468630
# 2022-01-01          0     0.953933
# 2022-02-01          0     0.952362
# 2022-03-01          4     1.290063
# 2022-04-01          2     1.778204
# 2022-05-01          1     2.228856
# 2022-06-01          0     2.531835
# 2022-07-01          0     2.677037
# 2022-08-01          7     2.687372
# 2022-09-01          1     2.607049
# 2022-10-01          1     2.461214
# ...

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
train = b.iloc[:280,2:3]
test = b.iloc[280:,2:3]

test
# Out:
#             TWITTER
# DATE
# 2021-12-17       25
# 2021-12-18       37
# 2021-12-19       50
# 2021-12-20       35
# 2021-12-21       37
# 2021-12-22       45
# 2021-12-23       31
# 2021-12-24       35
# 2021-12-25       41
# 2021-12-26        2
# 2021-12-27        0
# 2021-12-28        0
# 2021-12-29        0
# 2021-12-30        0
# 2021-12-31        0
# 2022-01-01        0
# 2022-02-01        0
# 2022-03-01        4
# 2022-04-01        4
# 2022-05-01        6
# 2022-06-01        0
# 2022-07-01        5
# 2022-08-01       10
# 2022-09-01        0
# 2022-10-01        7
# 2022-11-01        9
# 2022-12-01        8
# 2022-01-13       12
# 2022-01-14        4
# 2022-01-15        4
# 2022-01-19        0
# 2022-01-21        0
# 2022-01-22        0
# 2022-01-24        1
# 2022-01-25        0
# 2022-01-27        0
# 2022-01-28        0
# 2022-01-29        0
# 2022-01-31        0
# 2022-01-16        0

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
n_input = 30
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(n_input, n_features)))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# fit model
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 20s 51ms/step - loss: 0.0110
# Epoch 2/100
# 250/250 [==============================] - 12s 50ms/step - loss: 0.0108
# Epoch 3/100
# 250/250 [==============================] - 13s 51ms/step - loss: 0.0105
# Epoch 4/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0101
# Epoch 5/100
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0100
# Epoch 6/100
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0103
# Epoch 7/100
# 250/250 [==============================] - 13s 51ms/step - loss: 0.0101
# Epoch 8/100
# 250/250 [==============================] - 12s 50ms/step - loss: 0.0102
# Epoch 9/100
# 250/250 [==============================] - 14s 57ms/step - loss: 0.0099
# Epoch 10/100
# 250/250 [==============================] - 14s 56ms/step - loss: 0.0098
# Epoch 11/100
# 250/250 [==============================] - 14s 56ms/step - loss: 0.0098
# Epoch 12/100
# ...

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['Predictions'] = true_predictions

test
# Out:
#             TWITTER  Predictions
# DATE
# 2021-12-17       25    37.249206
# 2021-12-18       37    37.198014
# 2021-12-19       50    31.357001
# 2021-12-20       35    25.529814
# 2021-12-21       37    22.153870
# 2021-12-22       45    20.297360
# 2021-12-23       31    18.696023
# 2021-12-24       35    16.736846
# 2021-12-25       41    14.478221
# 2021-12-26        2    12.511071
# 2021-12-27        0    11.137962
# 2021-12-28        0    10.581003
# 2021-12-29        0    10.790712
# 2021-12-30        0    11.582652
# 2021-12-31        0    12.655276
# 2022-01-01        0    13.605995
# 2022-02-01        0    14.126915
# 2022-03-01        4    14.203564
# 2022-04-01        4    14.125151
# 2022-05-01        6    13.923352
# 2022-06-01        0    13.820702
# 2022-07-01        5    13.846548
# 2022-08-01       10    13.579620
# 2022-09-01        0    13.520330
# 2022-10-01        7    13.519584
# 2022-11-01        9    13.545861
# 2022-12-01        8    13.713728
# ...

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
train = b.iloc[:280,3:4]
test = b.iloc[280:,3:4]

test
# Out:
#             QUORA
# DATE
# 2021-12-17      0
# 2021-12-18      0
# 2021-12-19      0
# 2021-12-20      0
# 2021-12-21      0
# 2021-12-22      6
# 2021-12-23      0
# 2021-12-24      6
# 2021-12-25      0
# 2021-12-26      0
# 2021-12-27      0
# 2021-12-28      0
# 2021-12-29      0
# 2021-12-30     18
# 2021-12-31     18
# 2022-01-01      2
# 2022-02-01     20
# 2022-03-01     19
# 2022-04-01      0
# 2022-05-01     21
# 2022-06-01     32
# 2022-07-01     24
# 2022-08-01     23
# 2022-09-01     29
# 2022-10-01     26
# 2022-11-01     22
# 2022-12-01     30
# 2022-01-13     30
# 2022-01-14     22
# 2022-01-15     26
# 2022-01-19      0
# 2022-01-21      0
# 2022-01-22      0
# 2022-01-24      0
# 2022-01-25      0
# 2022-01-27      0
# 2022-01-28      0
# 2022-01-29      0
# 2022-01-31      0
# 2022-01-16      0

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
n_input = 30
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(n_input, n_features)))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_8 (LSTM)               (None, 30, 50)            10400
#
#  dropout_8 (Dropout)         (None, 30, 50)            0
#
#  lstm_9 (LSTM)               (None, 30, 50)            20200
#
#  dropout_9 (Dropout)         (None, 30, 50)            0
#
#  lstm_10 (LSTM)              (None, 30, 50)            20200
#
#  dropout_10 (Dropout)        (None, 30, 50)            0
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dropout_11 (Dropout)        (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# ...
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 18s 43ms/step - loss: 0.0117
# Epoch 2/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0121
# Epoch 3/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0104
# Epoch 4/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0102
# Epoch 5/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0118
# Epoch 6/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0102
# Epoch 7/100
# 250/250 [==============================] - 12s 50ms/step - loss: 0.0098
# Epoch 8/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0098
# Epoch 9/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0096
# Epoch 10/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0097
# Epoch 11/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0095
# Epoch 12/100
# ...

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['Predictions'] = true_predictions

test
# Out:
#             QUORA  Predictions
# DATE
# 2021-12-17      0     0.624699
# 2021-12-18      0     0.167280
# 2021-12-19      0    -0.245494
# 2021-12-20      0    -0.566291
# 2021-12-21      0    -0.756592
# 2021-12-22      6    -0.824927
# 2021-12-23      0    -0.788315
# 2021-12-24      6    -0.711707
# 2021-12-25      0    -0.643689
# 2021-12-26      0    -0.605047
# 2021-12-27      0    -0.593726
# 2021-12-28      0    -0.587005
# 2021-12-29      0    -0.602997
# 2021-12-30     18    -0.622488
# 2021-12-31     18    -0.633226
# 2022-01-01      2    -0.628718
# 2022-02-01     20    -0.622626
# 2022-03-01     19    -0.603514
# 2022-04-01      0    -0.590098
# 2022-05-01     21    -0.588773
# 2022-06-01     32    -0.584177
# 2022-07-01     24    -0.611634
# 2022-08-01     23    -0.624764
# 2022-09-01     29    -0.626400
# 2022-10-01     26    -0.623823
# 2022-11-01     22    -0.618289
# 2022-12-01     30    -0.610847
# 2022-01-13     30    -0.607831
# 2022-01-14     22    -0.607271
# ...

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
test
# Out:
#             QUORA  Predictions
# DATE
# 2021-12-17      0     0.624699
# 2021-12-18      0     0.167280
# 2021-12-19      0    -0.245494
# 2021-12-20      0    -0.566291
# 2021-12-21      0    -0.756592
# 2021-12-22      6    -0.824927
# 2021-12-23      0    -0.788315
# 2021-12-24      6    -0.711707
# 2021-12-25      0    -0.643689
# 2021-12-26      0    -0.605047
# 2021-12-27      0    -0.593726
# 2021-12-28      0    -0.587005
# 2021-12-29      0    -0.602997
# 2021-12-30     18    -0.622488
# 2021-12-31     18    -0.633226
# 2022-01-01      2    -0.628718
# 2022-02-01     20    -0.622626
# 2022-03-01     19    -0.603514
# 2022-04-01      0    -0.590098
# 2022-05-01     21    -0.588773
# 2022-06-01     32    -0.584177
# 2022-07-01     24    -0.611634
# 2022-08-01     23    -0.624764
# 2022-09-01     29    -0.626400
# 2022-10-01     26    -0.623823
# 2022-11-01     22    -0.618289
# 2022-12-01     30    -0.610847
# 2022-01-13     30    -0.607831
# 2022-01-14     22    -0.607271
# ...

# %%
plt.plot(test)
