# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")

# %% [markdown]
# ### Understanding the dataset

# %%
a=pd.read_csv("csvDumps/CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv")
a["INDEX"] = [i for i  in range(0,320)]
a.to_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv", index=False)
a
# Out:
#            DATE  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  \
# 0    28-05-2021         2          0        0      0         3      35
# 1    29-05-2021       116          1        0      0         0      18
# 2    30-05-2021        10          6        0      0         5      31
# 3    31-05-2021        39          0        1      0         1      70
# 4    01-06-2021        77         17        0      0         5      18
# ..          ...       ...        ...      ...    ...       ...     ...
# 315  27-01-2022         0          0        0      0         0       0
# 316  28-01-2022         0          0        0      0         0       0
# 317  29-01-2022         0          0        0      0         0       0
# 318  31-01-2022         0          0        0      0         0       0
# 319  16-01-2022         0          0        0      0         0       0
#
#      SNAPCHAT  YOUTUBE  TIKTOK  EMAIL  OTHER  INDEX
# 0           4        0       0      0      9      0
# 1           2        0       0      0      0      1
# 2           5        0       0      0      1      2
# 3           2        0       0      0      0      3
# 4           0        0       0      0      2      4
# ..        ...      ...     ...    ...    ...    ...
# 315         0        0       0      0      0    315
# 316         0        0       0      0      0    316
# 317         0        0       0      0      0    317
# 318         0        0       0      0      0    318
# 319         0        0       0      0      0    319
#
# [320 rows x 13 columns]

# %%
label=["FACEBOOK","INSTAGRAM","TWITTER","QUORA","LINKEDIN","REDDIT","SNAPCHAT","YOUTUBE","TIKTOK","EMAIL","OTHER"]

# %%
a.shape
# Out:
# (320, 13)

# %%
total_views=[int(sum(a['FACEBOOK'])),int(sum(a['INSTAGRAM'])),int(sum(a['TWITTER'])),int(sum(a['QUORA'])),int(sum(a['LINKEDIN'])),int(sum(a['REDDIT'])),int(sum(a['SNAPCHAT'])),int(sum(a['YOUTUBE'])),int(sum(a['TIKTOK'])),int(sum(a['EMAIL'])),int(sum(a['OTHER']))]
total_views
# Out:
# [10177, 3592, 7136, 1343, 1289, 7338, 845, 737, 0, 177, 1976]

# %% [markdown]
# ### Plotting every view of each platform against date
#
# This section plots every view of each platform against the respective date.
#
# As we understand, while Facebook, Instagram, Snapchat, LinkedIn and Reddit are well-used platform, the rest lack the required public engagement.
#
# The well-viewed platforms are identified from the graphs, where in all 320 days, the view is high. Similarly, the less viewed platforms have 320 rows with nearly 0 to less number of views, or even a high view on only 2-3 days max.

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(y=a['FACEBOOK'],x=a['INDEX'])
sns.scatterplot(y=a['INSTAGRAM'],x=a['INDEX'])
sns.scatterplot(y=a['TWITTER'],x=a['INDEX'])
sns.scatterplot(y=a['QUORA'],x=a['INDEX'])
sns.scatterplot(y=a['LINKEDIN'],x=a['INDEX'])
sns.scatterplot(y=a['REDDIT'],x=a['INDEX'])
sns.scatterplot(y=a['SNAPCHAT'],x=a['INDEX'])
sns.scatterplot(y=a['YOUTUBE'],x=a['INDEX'])
sns.scatterplot(y=a['TIKTOK'],x=a['INDEX'])
sns.scatterplot(y=a['EMAIL'],x=a['INDEX'])
sns.scatterplot(y=a['OTHER'],x=a['INDEX'])
plt.legend(label)
plt.figure(figsize=(20,20))

# %% [markdown]
# ### Plotting of sum of views for each platform for an overall analysis

# %%
plt.pie(total_views,labels=label,autopct='%.0f%%')
plt.title("PIECHART DEPICTING THE SUM OF ALL VISITS IN EACH PLATFORM")
plt.show()

# %%
label_short=["FB","IG","TW","QRA","LN","RDT","SNP","UT","TT","EM","O"]
sns.barplot(x=label_short, y=total_views)
plt.title("BARPLOT DEPICTING THE SUM OF ALL VIEWS FOR EACH PLATFORM")
plt.show()

# %% [markdown]
# ### Individual Analysis of each platform
#
# As mentioned, from the graph it is clear that the well-viewed apps include - Facebook, Instagram, Linkedin, reddit, snapchat, and likewise the rest fall under the less-viewed apps. For example, "Email" and "Tiktok" have almost 0 to no views at all in all the 320 days.
#
# Youtube and Quora have high views at the end of the graph. This means that only on certain end days, it has been used well. We want apps to be used daily. Hence a little focus is needed here as well.

# %%
fig, axs = plt.subplots(4, 3)
axs[0, 1].plot(a['FACEBOOK'])
axs[0, 1].set_title("FACEBOOK")
axs[0, 2].plot(a['INSTAGRAM'])
axs[0, 2].set_title("INSTAGRAM")
axs[1, 0].plot(a['TWITTER'])
axs[1, 0].set_title("TWITTER")
axs[1, 1].plot(a['QUORA'])
axs[1, 1].set_title("QUORA")
axs[1, 2].plot(a['LINKEDIN'])
axs[1, 2].set_title("LINKEDIN")
axs[2, 0].plot(a['REDDIT'])
axs[2, 0].set_title("REDDIT")
axs[2, 1].plot(a['SNAPCHAT'])
axs[2, 1].set_title("SNAPCHAT")
axs[2, 2].plot(a['YOUTUBE'])
axs[2, 2].set_title("YOUTUBE")
axs[3, 0].plot(a['TIKTOK'])
axs[3, 0].set_title("TIKTOK")
axs[3, 1].plot(a['EMAIL'])
axs[3, 1].set_title("EMAIL")
axs[0, 0].plot(a['OTHER'])
axs[0, 0].set_title("OTHERS")
plt.show()

# %% [markdown]
# ### Costructive analysis of well-viewed apps
#
# The apps here are : Facebook, Instagram, Linkedin, Reddit and Snapchat
#
# As we observe from the graph, Facebook and Snapchat are very well-viewed by users on a daily basis
#
# Instagram has lesser views than normal, hence more attention is needed.
#
# LinkedIn and Reddit do have good views but lesser than Facebook and snapchat.

# %%
fig, ax = plt.subplots(5, 2)

sns.distplot(a['FACEBOOK'], ax=ax[0,0]).set_title("FACEBOOK")
sns.scatterplot(y=a['FACEBOOK'],x=a['INDEX'], ax=ax[0,1]).set_title("FACEBOOK")
sns.distplot(a['INSTAGRAM'],ax=ax[1,0]).set_title("INSTAGRAM")
sns.scatterplot(y=a['INSTAGRAM'],x=a['INDEX'] ,ax=ax[1,1]).set_title("INSTAGRAM")
sns.distplot(a['LINKEDIN'],ax=ax[2,0]).set_title("LINKEDIN")
sns.scatterplot(y=a['LINKEDIN'],x=a['INDEX'] ,ax=ax[2,1]).set_title("LINKEDIN")
sns.distplot(a['REDDIT'],ax=ax[3,0]).set_title("REDDIT")
sns.scatterplot(y=a['REDDIT'],x=a['INDEX'] ,ax=ax[3,1]).set_title("REDDIT")
sns.distplot(a['SNAPCHAT'],ax=ax[4,0]).set_title("SNAPCHAT")
sns.scatterplot(y=a['SNAPCHAT'],x=a['INDEX'] ,ax=ax[4,1]).set_title("SNAPCHAT")
# Out:
# Text(0.5, 1.0, 'SNAPCHAT')

# %% [markdown]
# ### Constructive analysis of less-viewed apps
#
# Twitter has the most views among this lot, although less yet better than the others.
#
# Youtube and Quora have 0 views since most of the days, but 3-4 days at the end, we see a striking increase, which again diminishes.
#
# Tiktok has 0 views all through out, along with Email that has very scanty views all throughout.

# %%
fig, ax = plt.subplots(2, 3)
sns.scatterplot(y=a['TWITTER'],x=a['INDEX'] ,ax=ax[0,0]).set_title("TWITTER")
sns.scatterplot(y=a['QUORA'],x=a['INDEX'] ,ax=ax[0,1]).set_title("QUORA")
sns.scatterplot(y=a['YOUTUBE'],x=a['INDEX'] ,ax=ax[0,2]).set_title("YOUTUBE")
sns.scatterplot(y=a['TIKTOK'],x=a['INDEX'] ,ax=ax[1,0]).set_title("TIKTOK")
sns.scatterplot(y=a['EMAIL'],x=a['INDEX'] ,ax=ax[1,1]).set_title("EMAIL")
sns.scatterplot(y=a['OTHER'],x=a['INDEX'] ,ax=ax[1,2]).set_title("OTHER")
# Out:
# Text(0.5, 1.0, 'OTHER')

# %% [markdown]
# ### Model For Prediction

# %%
b=pd.read_csv("csvDumps\CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv",index_col='DATE',parse_dates=True)
b
# Out:
#             FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
# DATE
# 2021-05-28         2          0        0      0         3      35         4
# 2021-05-29       116          1        0      0         0      18         2
# 2021-05-30        10          6        0      0         5      31         5
# 2021-05-31        39          0        1      0         1      70         2
# 2021-01-06        77         17        0      0         5      18         0
# ...              ...        ...      ...    ...       ...     ...       ...
# 2022-01-27         0          0        0      0         0       0         0
# 2022-01-28         0          0        0      0         0       0         0
# 2022-01-29         0          0        0      0         0       0         0
# 2022-01-31         0          0        0      0         0       0         0
# 2022-01-16         0          0        0      0         0       0         0
#
#             YOUTUBE  TIKTOK  EMAIL  OTHER
# DATE
# 2021-05-28        0       0      0      9
# 2021-05-29        0       0      0      0
# 2021-05-30        0       0      0      1
# 2021-05-31        0       0      0      0
# 2021-01-06        0       0      0      2
# ...             ...     ...    ...    ...
# 2022-01-27        0       0      0      0
# 2022-01-28        0       0      0      0
# 2022-01-29        0       0      0      0
# 2022-01-31        0       0      0      0
# 2022-01-16        0       0      0      0
#
# [320 rows x 11 columns]

# %%
len(b)
# Out:
# 320

# %%
train = b.iloc[:280,0:1]
test = b.iloc[280:,0:1]

# %%
train
# Out:
#             FACEBOOK
# DATE
# 2021-05-28         2
# 2021-05-29       116
# 2021-05-30        10
# 2021-05-31        39
# 2021-01-06        77
# ...              ...
# 2021-12-12        50
# 2021-12-13        56
# 2021-12-14        59
# 2021-12-15        25
# 2021-12-16       107
#
# [280 rows x 1 columns]

# %%
b.dtypes
# Out:
# FACEBOOK     int64
# INSTAGRAM    int64
# TWITTER      int64
# QUORA        int64
# LINKEDIN     int64
# REDDIT       int64
# SNAPCHAT     int64
# YOUTUBE      int64
# TIKTOK       int64
# EMAIL        int64
# OTHER        int64
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
b.head(),b.tail()
# Out:
# (            FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
#  DATE
#  2021-05-28         2          0        0      0         3      35         4
#  2021-05-29       116          1        0      0         0      18         2
#  2021-05-30        10          6        0      0         5      31         5
#  2021-05-31        39          0        1      0         1      70         2
#  2021-01-06        77         17        0      0         5      18         0
#
#              YOUTUBE  TIKTOK  EMAIL  OTHER
#  DATE
#  2021-05-28        0       0      0      9
#  2021-05-29        0       0      0      0
#  2021-05-30        0       0      0      1
#  2021-05-31        0       0      0      0
#  2021-01-06        0       0      0      2  ,
#              FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
#  DATE
#  2022-01-27         0          0        0      0         0       0         0
#  2022-01-28         0          0        0      0         0       0         0
#  2022-01-29         0          0        0      0         0       0         0
#  2022-01-31         0          0        0      0         0       0         0
#  2022-01-16         0          0        0      0         0       0         0
#
#              YOUTUBE  TIKTOK  EMAIL  OTHER
#  DATE
#  2022-01-27        0       0      0      0
#  2022-01-28        0       0      0      0
#  2022-01-29        0       0      0      0
#  2022-01-31        0       0      0      0
#  2022-01-16        0       0      0      0  )

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.00687285],
#        [0.39862543],
#        [0.03436426],
#        [0.13402062],
#        [0.26460481],
#        [0.17869416],
#        [0.18213058],
#        [0.05841924],
#        [0.08591065],
#        [0.48109966]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
n_input = 30
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=32)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation, Dropout

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(n_input, n_features)))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 30, 50)            10400
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_2 (LSTM)               (None, 30, 50)            20200
#
#  dropout_1 (Dropout)         (None, 30, 50)            0
#
#  lstm_3 (LSTM)               (None, 30, 50)            20200
#
#  dropout_2 (Dropout)         (None, 30, 50)            0
#
#  lstm_4 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 17s 46ms/step - loss: 0.0241
# Epoch 2/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0230
# Epoch 3/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0219
# Epoch 4/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0219
# Epoch 5/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0217
# Epoch 6/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0209
# Epoch 7/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0201
# Epoch 8/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0207
# Epoch 9/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0187
# Epoch 10/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0204
# Epoch 11/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0187
# Epoch 12/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0202
# Epoch 13/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0191
# Epoch 14/100
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0181
# Epoch 15/100
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0196
# Epoch 16/100
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0182
# Epoch 17/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0184
# Epoch 18/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0181
# Epoch 19/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0181
# Epoch 20/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0185
# Epoch 21/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0182
# Epoch 22/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0178
# Epoch 23/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0184
# Epoch 24/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0184
# Epoch 25/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0183
# Epoch 26/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0183
# Epoch 27/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0179
# Epoch 28/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0175
# Epoch 29/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0179
# Epoch 30/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0174
# Epoch 31/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0174
# Epoch 32/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0179
# Epoch 33/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0174
# Epoch 34/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0172
# Epoch 35/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0172
# Epoch 36/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0174
# Epoch 37/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0181
# Epoch 38/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0181
# Epoch 39/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0176
# Epoch 40/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0177
# Epoch 41/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0173
# Epoch 42/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0177
# Epoch 43/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0173
# Epoch 44/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0175
# Epoch 45/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0176
# Epoch 46/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0173
# Epoch 47/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0176
# Epoch 48/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0178
# Epoch 49/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0182
# Epoch 50/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0179
# Epoch 51/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0171
# Epoch 52/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0173
# Epoch 53/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0170
# Epoch 54/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0175
# Epoch 55/100
# 250/250 [==============================] - 12s 50ms/step - loss: 0.0170
# Epoch 56/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0161
# Epoch 57/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0168
# Epoch 58/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0171
# Epoch 59/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0174
# Epoch 60/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0166
# Epoch 61/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0176
# Epoch 62/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0171
# Epoch 63/100
# 250/250 [==============================] - 10s 39ms/step - loss: 0.0167
# Epoch 64/100
# 250/250 [==============================] - 11s 42ms/step - loss: 0.0164
# Epoch 65/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0163
# Epoch 66/100
# 250/250 [==============================] - 10s 42ms/step - loss: 0.0201
# Epoch 67/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0174
# Epoch 68/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0163
# Epoch 69/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0174
# Epoch 70/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0164
# Epoch 71/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0159
# Epoch 72/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0167
# Epoch 73/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0157
# Epoch 74/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0167
# Epoch 75/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0162
# Epoch 76/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0143
# Epoch 77/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0171
# Epoch 78/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0186
# Epoch 79/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0163
# Epoch 80/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0168
# Epoch 81/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0156
# Epoch 82/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0145
# Epoch 83/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0137
# Epoch 84/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0128
# Epoch 85/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0177
# Epoch 86/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0123
# Epoch 87/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0115
# Epoch 88/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0130
# Epoch 89/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0134
# Epoch 90/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0110
# Epoch 91/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0126
# Epoch 92/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0113
# Epoch 93/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0110
# Epoch 94/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0108
# Epoch 95/100
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0108
# Epoch 96/100
# 250/250 [==============================] - 12s 46ms/step - loss: 0.0107
# Epoch 97/100
# 250/250 [==============================] - 11s 46ms/step - loss: 0.0118
# Epoch 98/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0117
# Epoch 99/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0086
# Epoch 100/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0112

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.2840451], dtype=float32),
#  array([0.24137446], dtype=float32),
#  array([0.24224535], dtype=float32),
#  array([0.40659484], dtype=float32),
#  array([0.42424482], dtype=float32),
#  array([0.2179428], dtype=float32),
#  array([0.1713044], dtype=float32),
#  array([0.21910378], dtype=float32),
#  array([0.3138957], dtype=float32),
#  array([0.2528065], dtype=float32),
#  array([0.23690459], dtype=float32),
#  array([0.23226464], dtype=float32),
#  array([0.2427054], dtype=float32),
#  array([0.27332258], dtype=float32),
#  array([0.32625785], dtype=float32),
#  array([0.3143521], dtype=float32),
#  array([0.26985314], dtype=float32),
#  array([0.3002081], dtype=float32),
#  array([0.30108973], dtype=float32),
#  array([0.24023059], dtype=float32),
#  array([0.24145421], dtype=float32),
#  array([0.23782203], dtype=float32),
#  array([0.25595915], dtype=float32),
#  array([0.27159935], dtype=float32),
#  array([0.27377486], dtype=float32),
#  array([0.2735713], dtype=float32),
#  array([0.2931899], dtype=float32),
#  array([0.3375769], dtype=float32),
#  array([0.33948547], dtype=float32),
#  array([0.29728913], dtype=float32),
#  array([0.2842015], dtype=float32),
#  array([0.3017283], dtype=float32),
#  array([0.28243107], dtype=float32),
#  array([0.25860503], dtype=float32),
#  array([0.25209728], dtype=float32),
#  array([0.2642458], dtype=float32),
#  array([0.2811687], dtype=float32),
#  array([0.28601882], dtype=float32),
#  array([0.28683177], dtype=float32),
#  array([0.30155364], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['Predictions'] = true_predictions

# %%
test
# Out:
#             FACEBOOK  Predictions
# DATE
# 2021-12-17        34    82.657124
# 2021-12-18        33    70.239969
# 2021-12-19        44    70.493396
# 2021-12-20        48   118.319099
# 2021-12-21        92   123.455243
# 2021-12-22        48    63.421356
# 2021-12-23        54    49.849582
# 2021-12-24        44    63.759201
# 2021-12-25        40    91.343649
# 2021-12-26         0    73.566696
# 2021-12-27         2    68.939236
# 2021-12-28         2    67.589010
# 2021-12-29         0    70.627273
# 2021-12-30         0    79.536871
# 2021-12-31         0    94.941036
# 2022-01-01         0    91.476460
# 2022-02-01         0    78.527265
# 2022-03-01        29    87.360555
# 2022-04-01         0    87.617113
# 2022-05-01         0    69.907102
# 2022-06-01         0    70.263176
# 2022-07-01         0    69.206210
# 2022-08-01         4    74.484114
# 2022-09-01         0    79.035412
# 2022-10-01         0    79.668485
# 2022-11-01         7    79.609252
# 2022-12-01         0    85.318265
# 2022-01-13         0    98.234877
# 2022-01-14         6    98.790271
# 2022-01-15         0    86.511138
# 2022-01-19         1    82.702637
# 2022-01-21         0    87.802938
# 2022-01-22         0    82.187440
# 2022-01-24         0    75.254065
# 2022-01-25         0    73.360308
# 2022-01-27         0    76.895530
# 2022-01-28         0    81.820091
# 2022-01-29         0    83.231476
# 2022-01-31         0    83.468044
# 2022-01-16         0    87.752108

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='DATE'>
