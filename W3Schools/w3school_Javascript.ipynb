# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
mainURL = "https://www.w3schools.com/js/default.asp"

page = requests.get(mainURL)
htmlContent = page.content
soup = BeautifulSoup(htmlContent, 'html.parser')

urls = []
pages = soup.find('div', {'id': 'leftmenuinnerinner'}).findAll(href=True)
for slug in pages:
    urls.append('https://www.w3schools.com/js/' + slug.get('href'))

mainHeadings = []
subHeadingsH2 = []
subHeadingsH3 = []
links = []
imageURLs = []
facts = []
definitions = []
explanations = []
codes = []
listItems = []
tableData = []
data = {}

# %%
for url in urls:
    page = requests.get(url)
    htmlContent = page.content
    soup = BeautifulSoup(htmlContent, 'html.parser')

    subContent = soup.find('div', {"id": "main"})  # Page Sub Content
    if subContent is None:
        continue

    mainHeading = subContent.findAll('h1')  # Main Heading
    pageMainHeadings = []
    if mainHeading is not None:
        for head in mainHeading:
            pageMainHeadings.append(head.text)

    subHeadingH2 = subContent.findAll('h2')  # Sub Headings h2
    pageSubHeadingsH2 = []
    if subHeadingH2 is not None:
        for head in subHeadingH2:
            pageSubHeadingsH2.append(head.text)

    subHeadingH3 = subContent.findAll('h3')  # Sub Headings h3
    pageSubHeadingsH3 = []
    if subHeadingH3 is not None:
        for head in subHeadingH3:
            pageSubHeadingsH3.append(head.text)

    link = subContent.findAll('a')  # Page Links
    pageLinks = []
    if link is not None:
        for lin in link:
            if lin.get('href') is not None and not lin.get('href').startswith('http'):
                pageLinks.append('https://www.w3schools.com/js/' + lin.get('href'))
            else:
                pageLinks.append(lin.get('href'))

    images = subContent.findAll('img')  # Images
    pageImageURLs = []
    if images is not None:
        for img in images:
            pageImageURLs.append('https://www.w3schools.com/js/' + img.get('src'))

    paragraphs = subContent.findAll('p')  # Paragraphs
    pageFacts = []
    pageDefinitions = []
    pageExplanations = []
    if paragraphs is not None:
        for para in paragraphs:
            slug = para.text.replace('\n', '')
            if 10 <= len(slug) <= 79:
                pageFacts.append(slug)
            elif 80 <= len(slug) <= 119:
                pageDefinitions.append(slug)
            elif 120 <= len(slug):
                pageExplanations.append(slug)

    codeContent = subContent.findAll('div', {"class": "w3-code"})  # Codes and Outputs
    pageCodes = []
    if codeContent is not None:
        for slug in codeContent:
            pageCodes.append(slug.text.replace('\xa0', ''))

    tables = subContent.findAll('table')  # Tables
    pageTableData = []
    if tables is not None:
        for tb in tables:
            table = ""
            rowData = []
            tableRows = tb.findAll('tr')
            for row in tableRows:
                rowData.append(row.text[1:-1].replace('\n', '|||'))
            for row in rowData:
                table = table + str(row) + '&&&'
            pageTableData.append(table[:-3])

    allListUL = subContent.findAll('ul')  # List Items
    allListOL = subContent.findAll('ol')
    listUL = ""
    listOL = ""
    listItem = ""
    pageListItems = []
    if len(allListUL) != 0 or len(allListOL) != 0:
        if len(allListUL) != 0:
            for lis in allListUL:
                listUL = listUL + str(lis.text[1:]).replace('\n', '|||').replace('\t\t', '')
        if len(allListOL) != 0:
            for lis in allListOL:
                listOL = listOL + str(lis.text[1:]).replace('\n', '|||').replace('\t\t', '')
        if len(allListUL) != 0 and len(allListOL) == 0:
            listItem = listItem + listUL
        elif len(allListUL) == 0 and len(allListOL) != 0:
            listItem = listItem + listOL
        else:
            listItem = listItem + listUL + '&&&' + listOL
        pageListItems.append(listItem)


    mainHeadings.append(pageMainHeadings)
    subHeadingsH2.append(pageSubHeadingsH2)
    subHeadingsH3.append(pageSubHeadingsH3)
    links.append(pageLinks)
    imageURLs.append(pageImageURLs)
    facts.append(pageFacts)
    definitions.append(pageDefinitions)
    explanations.append(pageExplanations)
    codes.append(pageCodes)
    tableData.append(pageTableData)
    listItems.append(pageListItems)

# %%
data = {'main_headings': mainHeadings, 'sub_headings_h2': subHeadingsH2, 'sub_headings_h3': subHeadingsH3,
        'links': links, 'image_urls': imageURLs, 'facts': facts, 'definitions': definitions,
        'explanations': explanations, 'codes': codes, 'table_data': tableData, 'list_items': listItems}

df = pd.DataFrame(data)
df.to_csv('W3Schools_Javascript.csv')

# %%
a=pd.read_csv("W3Schools_Javascript.csv")
a
# Out:
#      Unnamed: 0                            main_headings  \
# 0             0                  ['JavaScript Tutorial']
# 1             1              ['JavaScript Introduction']
# 2             2                  ['JavaScript Where To']
# 3             3                    ['JavaScript Output']
# 4             4                ['JavaScript Statements']
# ..          ...                                      ...
# 163         163  ['JavaScript Browser Objects Examples']
# 164         164             ['JavaScript Online Editor']
# 165         165                 ['JavaScript Exercises']
# 166         166                 ['JavaScript Quiz Test']
# 167         167     ['W3Schools JavaScript Certificate']
#
#                                        sub_headings_h2  \
# 0    ['Examples in Each Chapter', 'My First JavaScr...
# 1    ['JavaScript Can Change HTML Content', 'JavaSc...
# 2    ['The <script> Tag', 'JavaScript Functions and...
# 3    ['JavaScript Display Possibilities', 'Using in...
# 4    ['JavaScript Programs', 'JavaScript Statements...
# ..                                                 ...
# 163  ['Window Object', 'Screen Object', 'Location O...
# 164  ['JavaScript Editor', 'JavaScript Editor Expla...
# 165  ['Exercises', 'Count Your Score', 'Start JavaS...
# 166  ['The Test', 'Count Your Score', 'Start the Qu...
# 167  ['Document Your Skills', 'Get a Certificate', ...
#
#                                        sub_headings_h3  \
# 0                                          ['Example']
# 1    ['Example', 'Example', 'The Light Bulb', 'Exam...
# 2    ['Example', 'Example', 'Example', 'External fi...
# 3    ['Example', 'Example', 'Example', 'Example', '...
# 4    ['Example', 'Example', 'Examples', 'Example', ...
# ..                                                 ...
# 163                                                 []
# 164                                        ['Example']
# 165                                                 []
# 166                                                 []
# 167                                                 []
#
#                                                  links  \
# 0    ['https://www.w3schools.com/js//default.asp', ...
# 1    ['https://www.w3schools.com/js/default.asp', '...
# 2    ['https://www.w3schools.com/js/js_intro.asp', ...
# 3    ['https://www.w3schools.com/js/js_whereto.asp'...
# 4    ['https://www.w3schools.com/js/js_output.asp',...
# ..                                                 ...
# 163  ['https://www.w3schools.com/js/js_events_examp...
# 164  ['https://www.w3schools.com/js/js_ex_browser.a...
# 165  ['https://www.w3schools.com/js/js_editor.asp',...
# 166  ['https://www.w3schools.com/js/js_exercises.as...
# 167  ['https://www.w3schools.com/js/js_quiz.asp', '...
#
#                                             image_urls  \
# 0                                                   []
# 1     ['https://www.w3schools.com/js/pic_bulboff.gif']
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 163                                                 []
# 164                                                 []
# 165                                                 []
# 166                                                 []
# 167  ['https://www.w3schools.com/js//cert/pic_html_...
#
#                                                  facts  \
# 0    ["JavaScript is the world's most popular progr...
# 1    ['This page contains some examples of what Jav...
# 2    ['In HTML, JavaScript code is inserted between...
# 3    ['JavaScript can "display" data in different w...
# 4    ['A computer program is a list of "instruction...
# ..                                                 ...
# 163  ['Examples of using JavaScript to access and m...
# 164  ['Click on the "Try it Yourself" button to see...
# 165  ["You can test your JavaScript skills with W3S...
# 166  ["You can test your JavaScript skills with W3S...
# 167  ['W3Schools offers an Online Certification Pro...
#
#                                            definitions  \
# 0    ['With our "Try it Yourself" editor, you can e...
# 1    ['In this example JavaScript changes the value...
# 2    ['A JavaScript function is a block of JavaScri...
# 3    ['To access an HTML element, JavaScript can us...
# 4    ['In a programming language, these programming...
# ..                                                 ...
# 163                                                 []
# 164  ['With our online JavaScript editor, you can e...
# 165  ['We have gathered a variety of JavaScript exe...
# 166  ["The test is not official, it's just a nice w...
# 167  ['The perfect solution for busy professionals ...
#
#                                           explanations  \
# 0    ['The reference contains examples for all prop...
# 1    ['The example below "finds" an HTML element (w...
# 2    ['Old JavaScript examples may use a type attri...
# 3    ['In JavaScript, the window object is the glob...
# 4    ['On the web, you might see examples without s...
# ..                                                 ...
# 163                                                 []
# 164  ['The window to the left is editable - edit th...
# 165                                                 []
# 166  ['You will get 1 point for each correct answer...
# 167  ['Knowledge is power, especially in the curren...
#
#                                                  codes  \
# 0                                                   []
# 1    ['\n document.getElementById("demo").innerHTML...
# 2    ['\n<script>\ndocument.getElementById("demo")....
# 3    ['\n <!DOCTYPE html><html>\n<body>\n\n<h1>My F...
# 4    ['\nlet x, y, z; // Statement 1\nx = 5; // Sta...
# ..                                                 ...
# 163                                                 []
# 164     ['\nlet x = 5;\nlet y = 6;\nlet z = x + y;\n']
# 165                                                 []
# 166                                                 []
# 167                                                 []
#
#                                             table_data  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    ['Keyword|||Description&&&var|||Declares a var...
# ..                                                 ...
# 163                                                 []
# 164  ['Icon|||Description&&&|||Go to www.w3schools....
# 165                                                 []
# 166                                                 []
# 167  ['w3schools CERTIFIED  .  2021||||||\xa0\xa0||...
#
#                                             list_items
# 0    ['The Original JavaScript ES1 ES2 ES3 (1997-19...
# 1                                                   []
# 2    ['It separates HTML and code|||It makes HTML a...
# 3    ['Writing into an HTML element, using innerHTM...
# 4                                                   []
# ..                                                 ...
# 163                                                 []
# 164                                                 []
# 165                                                 []
# 166                                                 []
# 167  ['Study for free at W3Schools.com|||Study at y...
#
# [168 rows x 12 columns]
